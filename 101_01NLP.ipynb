# %% [markdown]
# # Understanding Natural Language Processing (NLP)

# %% [markdown]
# Natural Language Processing (NLP) is a subfield of artificial intelligence, machine learning, and linguistics. It focuses on enabling computers to understand, interpret, and generate human language in a way that is both meaningful and useful. Essentially, NLP bridges the gap between human communication and computer comprehension.

# %% [markdown]
# ## Why is NLP Important?
#
# *   **Bridging the Human-Computer Gap:** Allows computers to process and understand the vast amount of unstructured text data generated by humans daily.
# *   **Automation:** Automates tasks like translation, summarization, sentiment analysis, and question answering.
# *   **Enhanced User Experience:** Powers virtual assistants (Siri, Alexa), search engines, and recommendation systems.
# *   **Insights from Text:** Extracts valuable insights from social media, customer reviews, legal documents, and medical records.

# %% [markdown]
# ## Key Concepts and Tasks in NLP
#
# NLP involves several core components and tasks, often performed sequentially or iteratively.

# %% [markdown]
# ### 1. Text Preprocessing
#
# Before any analysis can begin, raw text data usually needs to be cleaned and prepared. Common preprocessing steps include:
#
# *   **Tokenization:** Breaking down text into smaller units (words, sentences).
# *   **Lowercasing:** Converting all text to lowercase to treat words like 'Apple' and 'apple' as the same.
# *   **Removing Stop Words:** Eliminating common words (e.g., 'the', 'is', 'a') that often carry little meaning for analysis.
# *   **Stemming/Lemmatization:** Reducing words to their root form (e.g., 'running', 'ran', 'runs' -> 'run'). Lemmatization is more sophisticated, ensuring the root is a valid word.

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# Download necessary NLTK data (run once)
try:
    nltk.data.find('tokenizers/punkt')
except nltk.downloader.DownloadError:
    nltk.download('punkt')
try:
    nltk.data.find('corpora/stopwords')
except nltk.downloader.DownloadError:
    nltk.download('stopwords')
try:
    nltk.data.find('corpora/wordnet')
except nltk.downloader.DownloadError:
    nltk.download('wordnet')

text = "Natural Language Processing (NLP) is an exciting field. It helps computers understand human language better."

# 1. Tokenization
tokens = word_tokenize(text)
print(f"Original text: {text}")
print(f"Tokens: {tokens}")

# 2. Lowercasing
lower_tokens = [word.lower() for word in tokens]
print(f"Lowercased tokens: {lower_tokens}")

# 3. Removing Stop Words
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in lower_tokens if word.isalnum() and word not in stop_words]
print(f"Filtered tokens (no stop words, no punctuation): {filtered_tokens}")

# 4. Stemming
stemmer = PorterStemmer()
stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]
print(f"Stemmed tokens: {stemmed_tokens}")

# 5. Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print(f"Lemmatized tokens: {lemmatized_tokens}")

# %% [markdown]
# ### 2. Part-of-Speech (POS) Tagging
#
# Assigning grammatical categories (e.g., noun, verb, adjective) to each word in a sentence. This helps in understanding the syntactic structure of the sentence.

# %%
import nltk

try:
    nltk.data.find('taggers/averaged_perceptron_tagger')
except nltk.downloader.DownloadError:
    nltk.download('averaged_perceptron_tagger')

text = "The quick brown fox jumps over the lazy dog."
tokens = nltk.word_tokenize(text)
pos_tags = nltk.pos_tag(tokens)

print(f"Text: {text}")
print(f"POS Tags: {pos_tags}")

# %% [markdown]
# ### 3. Named Entity Recognition (NER)
#
# Identifying and classifying named entities (e.g., persons, organizations, locations, dates) in text. This is crucial for information extraction.

# %%
import spacy

# Load English tokenizer, tagger, parser, and NER
try:
    nlp = spacy.load("en_core_web_sm")
except OSError:
    print("Downloading 'en_core_web_sm' model...")
    spacy.cli.download("en_core_web_sm")
    nlp = spacy.load("en_core_web_sm")

text = "Apple Inc. was founded by Steve Jobs and Steve Wozniak in Cupertino, California."
doc = nlp(text)

print(f"Text: {text}")
print("Named Entities:")
for ent in doc.ents:
    print(f"  {ent.text} ({ent.label_})")

# %% [markdown]
# ### 4. Sentiment Analysis
#
# Determining the emotional tone (positive, negative, neutral) expressed in a piece of text. Commonly used for analyzing customer feedback, social media, and product reviews.

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

try:
    nltk.data.find('sentiment/vader_lexicon')
except nltk.downloader.DownloadError:
    nltk.download('vader_lexicon')

analyser = SentimentIntensityAnalyzer()

def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    print(f"{{sentence}}: {{score}}")

sentiment_analyzer_scores("This is an amazing product! I love it.")
sentiment_analyzer_scores("The service was terrible and I'm very disappointed.")
sentiment_analyzer_scores("The movie was okay, nothing special.")

# %% [markdown]
# ### 5. Word Embeddings
#
# Representing words as dense vectors in a continuous vector space. Words with similar meanings are represented by similar vectors. This allows machine learning models to understand semantic relationships between words.
#
# Popular methods include:
# *   **Word2Vec:** Learns word associations from a large corpus of text.
# *   **GloVe (Global Vectors for Word Representation):** Combines global matrix factorization and local context window methods.
# *   **FastText:** An extension of Word2Vec that represents words as n-grams of characters, allowing it to handle out-of-vocabulary words.

# %%
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
import numpy as np

# Sample corpus
corpus = [
    "I love natural language processing.",
    "NLP is a fascinating field.",
    "Computers can understand human language with NLP.",
    "Machine learning is a part of AI."
]

# Tokenize and preprocess corpus
tokenized_corpus = [word_tokenize(sentence.lower()) for sentence in corpus]

# Train a Word2Vec model
model = Word2Vec(sentences=tokenized_corpus, vector_size=100, window=5, min_count=1, workers=4)

# Get vector for a word
word_vector = model.wv['nlp']
print(f"Vector for 'nlp':\n{word_vector[:5]}...") # print first 5 elements

# Find similar words
similar_words = model.wv.most_similar('language', topn=3)
print(f"Words similar to 'language': {similar_words}")

# Calculate similarity between two words
similarity = model.wv.similarity('nlp', 'language')
print(f"Similarity between 'nlp' and 'language': {similarity:.2f}")

# %% [markdown]
# ### 6. Transformers and Large Language Models (LLMs)
#
# The advent of the Transformer architecture has revolutionized NLP. Models like BERT, GPT, and their successors have achieved state-of-the-art performance across a wide range of tasks.
#
# *   **Transformers:** Utilize self-attention mechanisms to weigh the importance of different words in the input sequence, capturing long-range dependencies.
# *   **BERT (Bidirectional Encoder Representations from Transformers):** Pre-trained on a large corpus of text to understand context from both left and right of a word.
# *   **GPT (Generative Pre-trained Transformer):** Primarily a decoder-only model, excelling in text generation tasks, completing sentences, and answering questions.

# %%
from transformers import pipeline

# Load a pre-trained sentiment analysis model (using a BERT-based model internally)
sentiment_pipeline = pipeline("sentiment-analysis")

text1 = "I love using these new AI tools for writing."
text2 = "The weather today is just dreadful, I hate it."

result1 = sentiment_pipeline(text1)
result2 = sentiment_pipeline(text2)

print(f"Sentiment for '{{text1}}': {{result1}}")
print(f"Sentiment for '{{text2}}': {{result2}}")

# Example of text generation with a small GPT-2 model
generator = pipeline('text-generation', model='distilgpt2')

prompt = "Once upon a time, in a land far away, there was a dragon"
generated_text = generator(prompt, max_length=50, num_return_sequences=1)

print("\nGenerated Text:")
print(generated_text[0]['generated_text'])

# %% [markdown]
# ## Applications of NLP
#
# NLP is behind many technologies we use daily:
#
# *   **Machine Translation:** Google Translate, DeepL
# *   **Chatbots and Virtual Assistants:** Siri, Alexa, Google Assistant
# *   **Spam Detection:** Filtering unwanted emails
# *   **Text Summarization:** Condensing long documents into key points
# *   **Content Moderation:** Identifying harmful or inappropriate content
# *   **Information Retrieval:** Search engines
# *   **Medical Text Analysis:** Extracting information from patient records

# %% [markdown]
# ## Further Learning
#
# This is just a brief introduction to the vast field of NLP. To dive deeper, you might explore:
#
# *   **Advanced Models:** GPT-3, GPT-4, Llama, Falcon, etc.
# *   **Specific NLP Libraries:** Hugging Face Transformers, spaCy, NLTK, Gensim
# *   **Deep Learning for NLP:** Recurrent Neural Networks (RNNs), Long Short-Term Memory (LSTMs), Convolutional Neural Networks (CNNs) in the context of NLP.
# *   **Ethical Considerations:** Bias in models, data privacy.
