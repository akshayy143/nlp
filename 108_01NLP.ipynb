# %% [markdown]
# # RNN CODE IMPLIMENTATION

# %% [markdown]
# ![Screenshot 2026-04-24 100032.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-24 100500.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-24 100632.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-24 100720.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-24 101037.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-24 101317.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-24 101603.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-24 101632.png](data:image/png;base64,...)
