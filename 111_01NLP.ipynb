# %% [markdown]
# ![Screenshot 2026-04-27 100955.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-27 101250.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-27 101337.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-27 101413.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-27 101738.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-27 101808.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-27 102946.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-27 103133.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-27 103210.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-27 103257.png](data:image/png;base64,...)
